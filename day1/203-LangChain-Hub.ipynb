# %% [markdown]
# 다음은 LangChain Hub 에서 프롬프트를 받아서 실행하는 예제입니다.
#
# 아래 주소에서 LangChain Hub 프롬프트를 확인할 수 있습니다.
#
# 받아오는 방법은 프롬프트 repo 의 아이디 값을 가져 올 수 있고, commit id 를 붙여서 특정 버전에 대한 프롬프트를 받아올 수도 있습니다.

# %% [markdown]
# ## Hub로부터 Prompt 받아오기

# %%
from langchain import hub

# 가장 최신 버전의 프롬프트를 가져옵니다.
prompt = hub.pull("rlm/rag-prompt")

# %%
# 프롬프트 내용 출력
print(prompt)
# Out:
# input_variables=['context', 'question'] input_types={} partial_variables={} metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})]

# %%
# 특정 버전의 프롬프트를 가져오려면 버전 해시를 지정하세요
prompt = hub.pull("rlm/rag-prompt:50442af1")
prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})])

# %% [markdown]
# ## Prompt Hub 에 자신의 프롬프트 등록

# %%
from langchain.prompts import ChatPromptTemplate


prompt = ChatPromptTemplate.from_template(
    "주어진 내용을 바탕으로 다음 문장을 요약하세요. 답변은 반드시 한글로 작성하세요\n\nCONTEXT: {context}\n\nSUMMARY:"
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='주어진 내용을 바탕으로 다음 문장을 요약하세요. 답변은 반드시 한글로 작성하세요\n\nCONTEXT: {context}\n\nSUMMARY:'), additional_kwargs={})])

# %%
from langchain import hub

# 프롬프트를 허브에 업로드합니다.
hub.push("teddynote/simple-summary-korean", prompt)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\git\langchain-kr\.venv\Lib\site-packages\langsmith\utils.py:154, in raise_for_status_with_text(response)
#     153 try:
# --> 154     response.raise_for_status()
#     155 except requests.HTTPError as e:
#
# File d:\git\langchain-kr\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.smith.langchain.com/repos/teddynote/simple-summary-korean
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File d:\git\langchain-kr\.venv\Lib\site-packages\langsmith\client.py:840, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     834     response = self.session.request(
#     835         method,
#     836         _construct_url(self.api_url, pathname),
#     837         stream=False,
#     838         **request_kwargs,
#     839     )
# --> 840 ls_utils.raise_for_status_with_text(response)
#     841 return response
#
# File d:\git\langchain-kr\.venv\Lib\site-packages\langsmith\utils.py:156, in raise_for_status_with_text(response)
#     155 except requests.HTTPError as e:
# --> 156     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     157 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 403 Client Error: Forbidden for url: https://api.smith.langchain.com/repos/teddynote/simple-summary-korean] {"detail":"You are not the owner of this repo."}
#
# During handling of the above exception, another exception occurred:
#
# LangSmithError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 from langchain import hub
#       3 # 프롬프트를 허브에 업로드합니다.
# ----> 4 hub.push("teddynote/simple-summary-korean", prompt)
#
# File d:\git\langchain-kr\.venv\Lib\site-packages\langchain\hub.py:72, in push(repo_full_name, object, api_url, api_key, parent_commit_hash, new_repo_is_public, new_repo_description, readme, tags)
#      70 # Then it's langsmith
#      71 if hasattr(client, "push_prompt"):
# ---> 72     return client.push_prompt(
#      73         repo_full_name,
#      74         object=object,
#      75         parent_commit_hash=parent_commit_hash,
#      76         is_public=new_repo_is_public,
#      77         description=new_repo_description,
#      78         readme=readme,
#      79         tags=tags,
#      80     )
#      82 # Then it's langchainhub
#      83 manifest_json = dumps(object)
#
# File d:\git\langchain-kr\.venv\Lib\site-packages\langsmith\client.py:7324, in Client.push_prompt(self, prompt_identifier, object, parent_commit_hash, is_public, description, readme, tags)
#    7320 if self._prompt_exists(prompt_identifier):
#    7321     if any(
#    7322         param is not None for param in [is_public, description, readme, tags]
#    7323     ):
# -> 7324         self.update_prompt(
#    7325             prompt_identifier,
#    7326             description=description,
#    7327             readme=readme,
#    7328             tags=tags,
#    7329             is_public=is_public,
#    7330         )
#    7331 else:
#    7332     self.create_prompt(
#    7333         prompt_identifier,
#    7334         is_public=is_public if is_public is not None else False,
#    (...)   7337         tags=tags,
#    7338     )
#
# File d:\git\langchain-kr\.venv\Lib\site-packages\langsmith\client.py:7071, in Client.update_prompt(self, prompt_identifier, description, readme, tags, is_public, is_archived)
#    7068     json["tags"] = tags
#    7070 owner, prompt_name, _ = ls_utils.parse_prompt_identifier(prompt_identifier)
# -> 7071 response = self.request_with_retries(
#    7072     "PATCH", f"/repos/{owner}/{prompt_name}", json=json
#    7073 )
#    7074 response.raise_for_status()
#    7075 return response.json()
#
# File d:\git\langchain-kr\.venv\Lib\site-packages\langsmith\client.py:889, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#     885         raise ls_utils.LangSmithConflictError(
#     886             f"Conflict for {pathname}. {repr(e)}{_context}"
#     887         )
#     888     else:
# --> 889         raise ls_utils.LangSmithError(
#     890             f"Failed to {method} {pathname} in LangSmith"
#     891             f" API. {repr(e)}"
#     892         )
#     894 else:
#     895     raise ls_utils.LangSmithUserError(
#     896         f"Failed to {method} {pathname} in LangSmith API. {repr(e)}"
#     897     )
#
# LangSmithError: Failed to PATCH /repos/teddynote/simple-summary-korean in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/repos/teddynote/simple-summary-korean', '{"detail":"You are not the owner of this repo."}')

# %% [markdown]
# 다음은 Hub 에 성공적으로 업로드 된 후 출력입니다.
#
# `아이디/프롬프트명/해시`

# %% [markdown]
# > 출력: 'https://smith.langchain.com/hub/teddynote/simple-summary-korean/0e296563'

# %%
from langchain import hub

# 프롬프트를 허브로부터 가져옵니다.
pulled_prompt = hub.pull("teddynote/simple-summary-korean")

# %%
# 프롬프트 내용 출력
print(pulled_prompt)
# Out:
# input_variables=['context'] input_types={} partial_variables={} metadata={'lc_hub_owner': 'teddynote', 'lc_hub_repo': 'simple-summary-korean', 'lc_hub_commit_hash': 'b7e31df5666de7758d72fd038875973520d141548280185ee5b5ba846f015308'} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='주어진 내용을 바탕으로 다음 문장을 요약하세요. 답변은 반드시 한글로 작성하세요\n\nCONTEXT: {context}\n\nSUMMARY:'), additional_kwargs={})]
